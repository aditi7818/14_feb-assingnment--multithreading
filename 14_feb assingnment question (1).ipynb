# %%
Question: What is multithreading in python? why is it used? Name the module used to handle threads in python.
Answer: 
Multithreading is defined as the ability of a processor to execute multiple threads concurrently.

Multithreading in python
In python, the threading module provides a very simple and intuitive API for spawing multiple threads in a program. Let us try to understand multithreading code step-by-step.

# Step 1: Import Module
# first, import the threading module.

import threading module

# step 2: create a thread
# to create a new thread, we create an object of thread class. it takes the 'target' and 'args' as the parameters. the target is the function to be executed by the thread whereas
# the args is the arguments to be passed to the target function.

t1 = threading.Thread(target, args)
t2 = threading.Thread(target, args)

#step 3: start a thread, we use the start() method of the thread class.

t1.start()
t2.start()

#step 4: End the thread Execution
# once the threads start, the current program( you can think of it like a main thread) also keeps on executing. In order to stop the execution of the current program until a 
# thread is complete, we use the join() method.
t1.join()
t2.join()

# as a result, the current program will first wait for the completion of t1 and then t2. once, they are finished, the remaining statements of the current program are executed.

example:
Let us consider a simple example using a threding module

import therading
def print_cube(num):
    print("cube: {}".format(num*num*num))

def print_square(num):
    print("square: {}".format(num*num))
if __name__ = "__main__":
    t1 = threading.Thread(target = print_square, args = (10,))
    t2 = thraeding.Thread(target = print_cube, args= (10,))
    t1.start()
    t2.start()
    t1.join()
    t2.join()
    print("done!")
    
    
~ Use of multithreading:
    Multithreading allows many parts of a program to run simultaneously. These parts are referred to as threads, and they are lightwieght processes that are available within the 
    process. As a result, multithreading increases CPU utilization through multitasking. 

~ Name of module use to handle thread:
    
Methods                                                     Description

start()                                                     A start() method is used to initate  the activity of a thread. And it calls only once for each thread so that
                                                            the execution of the thread can begin.
    
run()                                                       A run() method is used to define a thread activity and can be overridden by a class that extends the threads class.

join()                                                      A join() method is used to block the execution of another code until the thread termenates.

# %%
Question: Why threading module used? write the use of the following functions:
    
1). activeCount()
2). currentThread()
3). enumerate()

Answer: 
python threading allows you to have different parts of your program run concurrently and can simplify your design. If you have got some experience in python and want to speed up 
your program in python and want to speed up your program using threads.

1). activecount(): Returns the number of thread objects that are active.

2). threading.currentThread(): Returns the number of thread objects in the caller thread control.

3). threading.enumerate(): Returns a list of all thread objects that are currently active.

# %%
Question: Explain the following functions:
1. run()
2. start()
3. join()
4. isAlive()

Answer:
1). run() - the run() method is the entry point for a thread.
2). start() - the start() method starts a thread by calling the run method.
3). join() - the join() waits for threads to terminate.
4). isAlive() - the isAlive methods checks wheter a thread is still executing.

# %%
Question: Write a python program to create two threads. Thread one must print the list of squares and rthe thread two must print the list of cubes.
Answer:
import threading

def print_cube(num):
    print("cube:{}".format(num*num*num))
def print_square(num):
    print("Square:{}".format(num*num))
if __nmae__ == "__main__":
    t1 = threading.Thread(target = print_square, args = (10,))
    t2 = threading.Thread(target = print_cube, args = (10,))
    t1.start()
    t2.start()
    t1.join()
    t2.join()
    print("Done!")

# %%
Question: State advantages and disadvantage of multithreading.
Answer:
Advantages:
1). Improved performance: Multithreading can help increase the overall perfomance of an application, especially on systems with multiple processors. It allows multiple tasks to run 
concurrently, utilizing the aviable CPU resorces more efficiently.

2). Responsiveness: IN a single-threaded enviornment, if a long-running task blocks the main thread, the entire application becomemes unresponsive. Multithreading can prevent this 
issue by running such tasks in spreade threads, ensuring the application remains responsive.

3). Better resouce utilization: Multithreading allows better utilization of system resources by keeping the CPU busy while for I/O opreations or other task to complete.

4). Simplified modeling: Some problems can be more naturally modeled using multiple threads. This makes the program easier to design, understand, and maintain.

5). Parallelism: Multithreading enables parallelism, which can lead to significant perfomance improvements in applications that can be divided into smaller, independent task.

Disadvantages:
1). Complexity: Multithreading adds complexity to the program, making it more difficult to design, implement, and debug. Developers need to be aware of synchronization, deadlocks, 
race conditions, and other concurrency-related issue.

2).Synchronization overhead: To avoid data corruption and maintain cosistency, developers must synchronize access to shared resources, which can result in additional overhead 
and reduced perfomance.

3). Context switching: Context switching between threads consumes CPU time and resources, which can lead to perfomance degradation if not managed efficiently.

4). Hard to predict behavior: Due to the concurrent nature of multithreading, the behaviour of the program can be hard to predict and reproduce, especially when it comes to debugging.

5). Limited by hardware: The perfomance benefits of multithreading are limited by the number of available cores or processors in the system. In some cases, excessive use of threads 
can lead to perfomance degradation instead of improvement.

IN CONCLUSION, 
multitherading in python can offer significant advantages in term of perfomance, responsive and resources utilization. however, it also introduces complexity aand potential issues
related to synchronization and

# %%
Question: Explain deadlocks and race conditions.
Answer: 
    
Race Condition: 
A race condition is a undesirable sitiuation that occurs when a device or system attempts to perfome two or more opreations at the same time, but because of the nature of 
the device or system, the opreations must be done in the proper sequence to be done correctly.
Race conditions are most commonly associated with computer science and programming. they occur when two computer program procrsses, or threads, attempts to access the same resource
at the same time and cause problems in the system.
Race conditions are considerd a common issue for multithreading applications.

Example Of race condition: 
A simple example of race condition is a light switch. In some homes, there are multiple light switches connected to a common ceilling light. When these types of circuits are used,
the switch position becomes irrelevelant. if the light is on, moving either switch from its current position turns the the light off, similarly, if the light is off, then moving 
either switch from its current position turns the light on.
with that in mind, imagine what might happen if two people tried to turn on the light using the different switches at the same time. One instruction might cancel the other or the two
actions might trip the circuit breaker.



Deadlock:
A deadlock is a concurrency failure mode where a thread or threads wait for a condition that never occurs.
The result is that the deadlock threads are unable to progress and the program is stuck or frozen and must be terminated forcefully.

Common examples of the cause of threading deadlocks include:
    
1. A thread that waits on itself(e.g. attempts to acquire the same mutex lock twice.)
2. Threads that wait on each other(e.g. A waits on B, B waits on A)
3. Thread that fails to release a resoures(e.g. mutex lock, semap

# %%
import threading

def print_cube(num):
    print("cube:{}". format(num*num))
def print_square(num):
          print("square:{}". format(num*num*num))
if __name__ == "__main__":
    t1 = threading.Thread(target = print_square, args = (45,))
    t2 = threading.Thread(target = print_cube, args = (24,))
    t1.start()
    t2.start()
    t1.join()
    t2.join()
    print("Done!")
# Out:
# square:91125
# cube:576
# Done!
